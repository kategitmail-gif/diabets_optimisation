# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_wine
from sklearn.discriminant_analysis import LinearDiscriminantAnalys
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.9.6 64-bit is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
(X,y) = load_wine(return_X_y = True, as_frame = True)
(n, p) = X.shape # number of examples and dimension of each example
K = y.unique().size # number of classes
print('n=', n, ', p=', p, ', K=', K)
Xy = pd.concat([X, y], axis=1) # X and y in a single data frame
# Out:
# Failed to start the Kernel.
#
# Kernel Python 3.9.6 64-bit is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
